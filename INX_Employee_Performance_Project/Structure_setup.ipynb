# %%
import os

project_root = "INX_Employee_Performance_Project"

folders = [
    "Project Summary/Requirement",
    "Project Summary/Analysis",
    "Project Summary/Summary",
    "data/raw",
    "data/processed",
    "data/external",
    "src/Data Processing",
    "src/models",
    "src/visualization",
    "references"
]

for folder in folders:
    os.makedirs(os.path.join(project_root, folder), exist_ok=True)

print("✅ IABAC folder structure created")
# Out:
# ✅ IABAC folder structure created
